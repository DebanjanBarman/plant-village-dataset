# %%
import cv2
import numpy as np
from PIL import Image
import os
from glob import glob

input_dir = "./Plant_Disease_Dataset_Unified/train/images"
output_dir = "./Plant_Disease_Dataset_Cleaned/train/images"

os.makedirs(output_dir, exist_ok=True)

for class_folder in glob(f"{input_dir}/*"):
    class_name = os.path.basename(class_folder)
    os.makedirs(os.path.join(output_dir, class_name), exist_ok=True)

    for image_path in glob(f"{class_folder}/*.jpg"):
        image = cv2.imread(image_path)
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Range for green leaves (tune if needed)
        lower = np.array([25, 40, 40])
        upper = np.array([85, 255, 255])

        mask = cv2.inRange(hsv, lower, upper)
        mask_inv = cv2.bitwise_not(mask)

        # Optional: remove small noise
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, np.ones((5,5), np.uint8))

        # Apply mask
        result = cv2.bitwise_and(image, image, mask=mask)

        # Save result
        out_path = os.path.join(output_dir, class_name, os.path.basename(image_path))
        Image.fromarray(cv2.cvtColor(result, cv2.COLOR_BGR2RGB)).save(out_path)

# %%
import cv2
import numpy as np
from PIL import Image
import os
from glob import glob
from tqdm import tqdm

input_dir = "./Plant_Disease_Dataset_Unified/train/images"
output_cleaned = "./Plant_Disease_Dataset_Cleaned/train/images"
output_comparison = "./Plant_Disease_Dataset_Cleaned/train/comparisons"

os.makedirs(output_cleaned, exist_ok=True)
os.makedirs(output_comparison, exist_ok=True)

class_folders = glob(f"{input_dir}/*")

for class_folder in tqdm(class_folders, desc="Processing classes"):
    class_name = os.path.basename(class_folder)
    class_output_path = os.path.join(output_cleaned, class_name)
    class_cmp_path = os.path.join(output_comparison, class_name)

    os.makedirs(class_output_path, exist_ok=True)
    os.makedirs(class_cmp_path, exist_ok=True)

    image_paths = glob(f"{class_folder}/*.jpg")
    
    for image_path in tqdm(image_paths, desc=f"  -> {class_name}", leave=False):
        img_name = os.path.basename(image_path)

        # Read image
        image = cv2.imread(image_path)
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # HSV range — broad to include green + yellow/brown
        lower = np.array([15, 30, 30])
        upper = np.array([100, 255, 255])
        mask = cv2.inRange(hsv, lower, upper)

        # Morphological cleaning
        kernel = np.ones((5, 5), np.uint8)
        mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

        # Apply mask to original
        result = cv2.bitwise_and(image, image, mask=mask)

        # White background
        white_bg = np.full_like(image, 255)
        inv_mask = cv2.bitwise_not(mask)
        background = cv2.bitwise_and(white_bg, white_bg, mask=inv_mask)
        final = cv2.add(result, background)

        # Save cleaned
        cleaned_path = os.path.join(class_output_path, img_name)
        Image.fromarray(cv2.cvtColor(final, cv2.COLOR_BGR2RGB)).save(cleaned_path)

        # Create side-by-side comparison
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        final_rgb = cv2.cvtColor(final, cv2.COLOR_BGR2RGB)
        side_by_side = np.hstack((image_rgb, final_rgb))
        cmp_path = os.path.join(class_cmp_path, f"cmp_{img_name}")
        Image.fromarray(side_by_side).save(cmp_path)

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import models, transforms
import torch
from tqdm import tqdm

# Load Pretrained DeepLabV3
def load_model():
    model = models.segmentation.deeplabv3_resnet101(pretrained=True)
    model.eval()
    return model

# Preprocess image
def preprocess_image(image_path):
    input_image = Image.open(image_path).convert("RGB")
    preprocess = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    return preprocess(input_image).unsqueeze(0), input_image

# Background removal using DeepLabV3
def remove_background(image_path, model):
    input_tensor, original_image = preprocess_image(image_path)
    with torch.no_grad():
        output = model(input_tensor)['out'][0]
    mask = output.argmax(0).byte().cpu().numpy()
    image_np = np.array(original_image)
    image_np[mask == 0] = 255  # white background
    return Image.fromarray(image_np), mask, original_image

# Save processed image
def save_processed_image(output_image, save_path):
    output_image.save(save_path)

# Save comparison image
def visualize_results(image_path, output_image, original_image, mask, comparison_save_path):
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(original_image)
    axes[0].set_title("Original")
    axes[0].axis("off")
    axes[1].imshow(output_image)
    axes[1].set_title("Background Removed")
    axes[1].axis("off")
    plt.tight_layout()
    plt.savefig(comparison_save_path)
    plt.close()

# Preserve original class structure
def create_class_structure(image_path, base_folder):
    class_name = os.path.normpath(image_path).split(os.sep)[-2]
    class_folder = os.path.join(base_folder, class_name)
    os.makedirs(class_folder, exist_ok=True)
    return class_folder

# Main processing function
def process_images_in_folder(image_folder, output_folder, comparison_folder):
    model = load_model()

    # Collect all image paths recursively
    image_paths = []
    for root, _, files in os.walk(image_folder):
        for f in files:
            if f.lower().endswith(('.jpg', '.png')):
                image_paths.append(os.path.join(root, f))

    print(f"[INFO] Found {len(image_paths)} images.")
    os.makedirs(output_folder, exist_ok=True)
    os.makedirs(comparison_folder, exist_ok=True)

    for img_path in tqdm(image_paths, desc="Processing images"):
        try:
            output_image, mask, original_image = remove_background(img_path, model)

            # Get class structure
            class_output_folder = create_class_structure(img_path, output_folder)
            class_comparison_folder = create_class_structure(img_path, comparison_folder)

            filename = os.path.basename(img_path)
            save_path = os.path.join(class_output_folder, filename)
            comparison_path = os.path.join(class_comparison_folder, f"comparison_{filename}")

            save_processed_image(output_image, save_path)
            visualize_results(img_path, output_image, original_image, mask, comparison_path)
        except Exception as e:
            print(f"[ERROR] Failed to process {img_path}: {e}")

# Example usage
image_folder = "./Plant_Disease_Dataset_Unified/train/images"  # Original images
output_folder = "./Processed_Images"  # Background removed images
comparison_folder = "./Comparison_Images"  # Side-by-side comparisons

process_images_in_folder(image_folder, output_folder, comparison_folder)

# %%
import os
from rembg import remove
from PIL import Image
from tqdm import tqdm

# Set input and output base directories
input_base = './Plant_Disease_Dataset_Unified/train/images'
output_base = './Plant_Disease_Dataset_Unified/train/images_nobg'
comparison_base = './Plant_Disease_Dataset_Unified/train/images_comparison'

# Ensure output and comparison directories exist
os.makedirs(output_base, exist_ok=True)
os.makedirs(comparison_base, exist_ok=True)

# Walk through the class directories
for class_name in tqdm(os.listdir(input_base), desc="Processing classes"):
    class_input_path = os.path.join(input_base, class_name)
    class_output_path = os.path.join(output_base, class_name)
    class_comparison_path = os.path.join(comparison_base, class_name)

    # Skip non-directories
    if not os.path.isdir(class_input_path):
        continue

    os.makedirs(class_output_path, exist_ok=True)
    os.makedirs(class_comparison_path, exist_ok=True)

    image_files = [f for f in os.listdir(class_input_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    for image_file in tqdm(image_files, desc=f"Removing background: {class_name}", leave=False):
        input_image_path = os.path.join(class_input_path, image_file)
        output_image_path = os.path.join(class_output_path, image_file)
        comparison_image_path = os.path.join(class_comparison_path, image_file)

        try:
            input_image = Image.open(input_image_path).convert("RGB")
            output_image = remove(input_image)

            # Check the output file extension for saving
            ext = os.path.splitext(output_image_path)[1].lower()
            if ext in ['.jpg', '.jpeg']:
                output_image.convert("RGB").save(output_image_path, format="JPEG")
            elif ext == '.png':
                output_image.save(output_image_path, format="PNG")
            else:
                output_image.save(output_image_path)

            # Create side-by-side comparison image
            comparison_width = input_image.width + output_image.width
            comparison_height = max(input_image.height, output_image.height)
            comparison = Image.new("RGB", (comparison_width, comparison_height))
            comparison.paste(input_image, (0, 0))
            comparison.paste(output_image, (input_image.width, 0))

            # Save comparison image
            comparison.save(comparison_image_path)

        except Exception as e:
            print(f"[Error] Failed on {input_image_path}: {e}")
# Out:
# Removing background: Apple___Apple_scab:   3%|██▍                                                                                        | 55/2016 [00:54<32:26,  1.01it/s]
# Removing background: Apple___Apple_scab:   3%|██▌                                                                                        | 56/2016 [00:55<33:02,  1.01s/it]
# Removing background: Apple___Apple_scab:   3%|██▌                                                                                        | 57/2016 [00:56<33:15,  1.02s/it]
# Removing background: Apple___Apple_scab:   3%|██▌                                                                                        | 58/2016 [00:57<33:17,  1.02s/it]
# Removing background: Apple___Apple_scab:   3%|██▋                                                                                        | 59/2016 [00:58<34:02,  1.04s/it]
# Removing background: Apple___Apple_scab:   3%|██▋                                                                                        | 60/2016 [00:59<33:21,  1.02s/it]
# Removing background: Apple___Apple_scab:   3%|██▊                                                                                        | 61/2016 [01:00<33:26,  1.03s/it]
# Removing background: Apple___Apple_scab:   3%|██▊                                                                                        | 62/2016 [01:01<32:41,  1.00s/it]
# Removing background: Apple___Apple_scab:   3%|██▊                                                                                        | 63/2016 [01:02<32:21,  1.01it/s]
# Removing background: Apple___Apple_scab:   3%|██▉                                                                                        | 64/2016 [01:03<32:00,  1.02it/s]
# Removing background: Apple___Apple_scab:   3%|██▉                                                                                        | 65/2016 [01:04<32:23,  1.00it/s]
# Removing background: Apple___Apple_scab:   3%|██▉                                                                                        | 66/2016 [01:05<32:26,  1.00it/s]
# Removing background: Apple___Apple_scab:   3%|███                                                                                        | 67/2016 [01:06<32:15,  1.01it/s]
# Removing background: Apple___Apple_scab:   3%|███                                                                                        | 68/2016 [01:07<31:37,  1.03it/s]
# Removing background: Apple___Apple_scab:   3%|███                                                                                        | 69/2016 [01:08<32:08,  1.01it/s]
# Removing background: Apple___Apple_scab:   3%|███▏                                                                                       | 70/2016 [01:09<32:10,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▏                                                                                       | 71/2016 [01:10<32:13,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▎                                                                                       | 72/2016 [01:11<32:20,  1.00it/s]
# Removing background: Apple___Apple_scab:   4%|███▎                                                                                       | 73/2016 [01:12<32:35,  1.01s/it]
# Removing background: Apple___Apple_scab:   4%|███▎                                                                                       | 74/2016 [01:13<32:22,  1.00s/it]
# Removing background: Apple___Apple_scab:   4%|███▍                                                                                       | 75/2016 [01:14<32:17,  1.00it/s]
# Removing background: Apple___Apple_scab:   4%|███▍                                                                                       | 76/2016 [01:15<32:09,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▍                                                                                       | 77/2016 [01:16<32:50,  1.02s/it]
# Removing background: Apple___Apple_scab:   4%|███▌                                                                                       | 78/2016 [01:17<32:19,  1.00s/it]
# Removing background: Apple___Apple_scab:   4%|███▌                                                                                       | 79/2016 [01:18<32:01,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▌                                                                                       | 80/2016 [01:19<31:49,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▋                                                                                       | 81/2016 [01:20<31:54,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▋                                                                                       | 82/2016 [01:21<32:01,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▋                                                                                       | 83/2016 [01:22<32:00,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▊                                                                                       | 84/2016 [01:23<31:52,  1.01it/s]
# Removing background: Apple___Apple_scab:   4%|███▊                                                                                       | 85/2016 [01:24<32:13,  1.00s/it]
# Removing background: Apple___Apple_scab:   4%|███▉                                                                                       | 86/2016 [01:25<32:05,  1.00it/s]
# Removing background: Apple___Apple_scab:   4%|███▉                                                                                       | 87/2016 [01:26<32:17,  1.00s/it]
# Removing background: Apple___Apple_scab:   4%|███▉                                                                                       | 88/2016 [01:27<32:32,  1.01s/it]
# Removing background: Apple___Apple_scab:   4%|████                                                                                       | 89/2016 [01:28<32:56,  1.03s/it]
# Removing background: Apple___Apple_scab:   4%|████                                                                                       | 90/2016 [01:29<32:49,  1.02s/it]
# Removing background: Apple___Apple_scab:   5%|████                                                                                       | 91/2016 [01:30<32:26,  1.01s/it]
# Removing background: Apple___Apple_scab:   5%|████▏                                                                                      | 92/2016 [01:31<32:55,  1.03s/it]
# Removing background: Apple___Apple_scab:   5%|████▏                                                                                      | 93/2016 [01:32<33:05,  1.03s/it]
# Removing background: Apple___Apple_scab:   5%|████▏                                                                                      | 94/2016 [01:33<33:12,  1.04s/it]
# Removing background: Apple___Apple_scab:   5%|████▎                                                                                      | 95/2016 [01:34<32:23,  1.01s/it]
# Removing background: Apple___Apple_scab:   5%|████▎                                                                                      | 96/2016 [01:36<33:27,  1.05s/it]
# Removing background: Apple___Apple_scab:   5%|████▍                                                                                      | 97/2016 [01:37<33:44,  1.06s/it]
# Removing background: Apple___Apple_scab:   5%|████▍                                                                                      | 98/2016 [01:38<33:12,  1.04s/it]
# Removing background: Apple___Apple_scab:   5%|████▍                                                                                      | 99/2016 [01:39<32:57,  1.03s/it]
# Removing background: Apple___Apple_scab:   5%|████▍                                                                                     | 100/2016 [01:40<32:29,  1.02s/it]
# Removing background: Apple___Apple_scab:   5%|████▌                                                                                     | 101/2016 [01:41<32:36,  1.02s/it]
# Removing background: Apple___Apple_scab:   5%|████▌                                                                                     | 102/2016 [01:42<33:25,  1.05s/it]
# Removing background: Apple___Apple_scab:   5%|████▌                                                                                     | 103/2016 [01:43<32:38,  1.02s/it]
# Removing background: Apple___Apple_scab:   5%|████▋                                                                                     | 104/2016 [01:44<32:06,  1.01s/it]
# Removing background: Apple___Apple_scab:   5%|████▋                                                                                     | 105/2016 [01:45<32:09,  1.01s/it]
# Removing background: Apple___Apple_scab:   5%|████▋                                                                                     | 106/2016 [01:46<32:02,  1.01s/it]
# Removing background: Apple___Apple_scab:   5%|████▊                                                                                     | 107/2016 [01:47<31:31,  1.01it/s]
# Removing background: Apple___Apple_scab:   5%|████▊                                                                                     | 108/2016 [01:48<31:53,  1.00s/it]
# Removing background: Apple___Apple_scab:   5%|████▊                                                                                     | 109/2016 [01:49<31:59,  1.01s/it]
# Removing background: Apple___Apple_scab:   5%|████▉                                                                                     | 110/2016 [01:50<32:03,  1.01s/it]
# Removing background: Apple___Apple_scab:   6%|████▉                                                                                     | 111/2016 [01:51<32:14,  1.02s/it]
# Removing background: Apple___Apple_scab:   6%|█████                                                                                     | 112/2016 [01:52<32:49,  1.03s/it]
# Removing background: Apple___Apple_scab:   6%|█████                                                                                     | 113/2016 [01:53<33:31,  1.06s/it]
# Removing background: Apple___Apple_scab:   6%|█████                                                                                     | 114/2016 [01:54<33:15,  1.05s/it]
# Removing background: Apple___Apple_scab:   6%|█████▏                                                                                    | 115/2016 [01:55<32:46,  1.03s/it]
# Removing background: Apple___Apple_scab:   6%|█████▏                                                                                    | 116/2016 [01:56<32:43,  1.03s/it]
# Removing background: Apple___Apple_scab:   6%|█████▏                                                                                    | 117/2016 [01:57<32:40,  1.03s/it]
# Removing background: Apple___Apple_scab:   6%|█████▎                                                                                    | 118/2016 [01:58<32:30,  1.03s/it]
# Removing background: Apple___Apple_scab:   6%|█████▎                                                                                    | 119/2016 [01:59<32:22,  1.02s/it]
# Removing background: Apple___Apple_scab:   6%|█████▎                                                                                    | 120/2016 [02:00<32:16,  1.02s/it]
# Removing background: Apple___Apple_scab:   6%|█████▍                                                                                    | 121/2016 [02:01<31:45,  1.01s/it]
# Removing background: Apple___Apple_scab:   6%|█████▍                                                                                    | 122/2016 [02:02<31:49,  1.01s/it]
# Removing background: Apple___Apple_scab:   6%|█████▍                                                                                    | 123/2016 [02:03<31:52,  1.01s/it]
# Removing background: Apple___Apple_scab:   6%|█████▌                                                                                    | 124/2016 [02:04<31:45,  1.01s/it]
# Removing background: Apple___Apple_scab:   6%|█████▌                                                                                    | 125/2016 [02:05<31:31,  1.00s/it]
# Removing background: Apple___Apple_scab:   6%|█████▋                                                                                    | 126/2016 [02:06<31:39,  1.00s/it]
# Removing background: Apple___Apple_scab:   6%|█████▋                                                                                    | 127/2016 [02:07<31:52,  1.01s/it]
# Removing background: Apple___Apple_scab:   6%|█████▋                                                                                    | 128/2016 [02:08<32:02,  1.02s/it]
# Removing background: Apple___Apple_scab:   6%|█████▊                                                                                    | 129/2016 [02:09<31:59,  1.02s/it]
# Removing background: Apple___Apple_scab:   6%|█████▊                                                                                    | 130/2016 [02:10<33:17,  1.06s/it]
# Removing background: Apple___Apple_scab:   6%|█████▊                                                                                    | 131/2016 [02:11<33:00,  1.05s/it]
# Removing background: Apple___Apple_scab:   7%|█████▉                                                                                    | 132/2016 [02:12<32:48,  1.04s/it]
# Removing background: Apple___Apple_scab:   7%|█████▉                                                                                    | 133/2016 [02:13<32:39,  1.04s/it]
# Removing background: Apple___Apple_scab:   7%|█████▉                                                                                    | 134/2016 [02:14<32:06,  1.02s/it]
# Removing background: Apple___Apple_scab:   7%|██████                                                                                    | 135/2016 [02:15<31:25,  1.00s/it]
# Removing background: Apple___Apple_scab:   7%|██████                                                                                    | 136/2016 [02:16<32:15,  1.03s/it]
# Removing background: Apple___Apple_scab:   7%|██████                                                                                    | 137/2016 [02:17<32:06,  1.03s/it]
# Removing background: Apple___Apple_scab:   7%|██████▏                                                                                   | 138/2016 [02:18<32:26,  1.04s/it]
# Removing background: Apple___Apple_scab:   7%|██████▏                                                                                   | 139/2016 [02:19<31:38,  1.01s/it]
# Removing background: Apple___Apple_scab:   7%|██████▎                                                                                   | 140/2016 [02:20<31:48,  1.02s/it]
# Removing background: Apple___Apple_scab:   7%|██████▎                                                                                   | 141/2016 [02:21<31:28,  1.01s/it]
# Removing background: Apple___Apple_scab:   7%|██████▎                                                                                   | 142/2016 [02:22<31:32,  1.01s/it]
# Removing background: Apple___Apple_scab:   7%|██████▍                                                                                   | 143/2016 [02:23<31:16,  1.00s/it]
# Removing background: Apple___Apple_scab:   7%|██████▍                                                                                   | 144/2016 [02:24<31:14,  1.00s/it]
# Removing background: Apple___Apple_scab:   7%|██████▍                                                                                   | 145/2016 [02:25<30:46,  1.01it/s]
# Removing background: Apple___Apple_scab:   7%|██████▌                                                                                   | 146/2016 [02:26<30:35,  1.02it/s]
# Removing background: Apple___Apple_scab:   7%|██████▌                                                                                   | 147/2016 [02:27<30:53,  1.01it/s]
# Removing background: Apple___Apple_scab:   7%|██████▌                                                                                   | 148/2016 [02:28<30:30,  1.02it/s]
# Removing background: Apple___Apple_scab:   7%|██████▋                                                                                   | 149/2016 [02:29<30:23,  1.02it/s]
# Removing background: Apple___Apple_scab:   7%|██████▋                                                                                   | 150/2016 [02:30<30:18,  1.03it/s]
# Removing background: Apple___Apple_scab:   7%|██████▋                                                                                   | 151/2016 [02:31<30:40,  1.01it/s]
# Removing background: Apple___Apple_scab:   8%|██████▊                                                                                   | 152/2016 [02:32<30:20,  1.02it/s]
# Removing background: Apple___Apple_scab:   8%|██████▊                                                                                   | 153/2016 [02:33<30:32,  1.02it/s]
# Removing background: Apple___Apple_scab:   8%|██████▉                                                                                   | 154/2016 [02:34<30:31,  1.02it/s]
# Removing background: Apple___Apple_scab:   8%|██████▉                                                                                   | 155/2016 [02:35<30:39,  1.01it/s]
# Removing background: Apple___Apple_scab:   8%|██████▉                                                                                   | 156/2016 [02:36<30:27,  1.02it/s]
# Removing background: Apple___Apple_scab:   8%|███████                                                                                   | 157/2016 [02:37<30:18,  1.02it/s]
# Removing background: Apple___Apple_scab:   8%|███████                                                                                   | 158/2016 [02:38<30:29,  1.02it/s]
# Removing background: Apple___Apple_scab:   8%|███████                                                                                   | 159/2016 [02:39<30:45,  1.01it/s]
# Removing background: Apple___Apple_scab:   8%|███████▏                                                                                  | 160/2016 [02:40<30:30,  1.01it/s]
# Removing background: Apple___Apple_scab:   8%|███████▏                                                                                  | 161/2016 [02:41<30:37,  1.01it/s]
# Removing background: Apple___Apple_scab:   8%|███████▏                                                                                  | 162/2016 [02:42<31:07,  1.01s/it]
# Removing background: Apple___Apple_scab:   8%|███████▎                                                                                  | 163/2016 [02:43<30:53,  1.00s/it]
# Removing background: Apple___Apple_scab:   8%|███████▎                                                                                  | 164/2016 [02:44<30:34,  1.01it/s]
# Removing background: Apple___Apple_scab:   8%|███████▎                                                                                  | 165/2016 [02:45<30:47,  1.00it/s]
# Removing background: Apple___Apple_scab:   8%|███████▍                                                                                  | 166/2016 [02:46<30:56,  1.00s/it]
# Removing background: Apple___Apple_scab:   8%|███████▍                                                                                  | 167/2016 [02:47<30:44,  1.00it/s]
# Removing background: Apple___Apple_scab:   8%|███████▌                                                                                  | 168/2016 [02:48<30:44,  1.00it/s]
# Removing background: Apple___Apple_scab:   8%|███████▌                                                                                  | 169/2016 [02:49<31:10,  1.01s/it]
# Removing background: Apple___Apple_scab:   8%|███████▌                                                                                  | 170/2016 [02:50<31:19,  1.02s/it]
# Removing background: Apple___Apple_scab:   8%|███████▋                                                                                  | 171/2016 [02:51<31:34,  1.03s/it]
# Removing background: Apple___Apple_scab:   9%|███████▋                                                                                  | 172/2016 [02:52<31:35,  1.03s/it]
# Removing background: Apple___Apple_scab:   9%|███████▋                                                                                  | 173/2016 [02:53<31:27,  1.02s/it]
# Removing background: Apple___Apple_scab:   9%|███████▊                                                                                  | 174/2016 [02:54<31:21,  1.02s/it]
# Removing background: Apple___Apple_scab:   9%|███████▊                                                                                  | 175/2016 [02:55<31:16,  1.02s/it]
# Removing background: Apple___Apple_scab:   9%|███████▊                                                                                  | 176/2016 [02:56<30:55,  1.01s/it]
# Removing background: Apple___Apple_scab:   9%|███████▉                                                                                  | 177/2016 [02:57<30:37,  1.00it/s]
# Removing background: Apple___Apple_scab:   9%|███████▉                                                                                  | 178/2016 [02:58<30:07,  1.02it/s]
# Removing background: Apple___Apple_scab:   9%|███████▉                                                                                  | 179/2016 [02:59<30:04,  1.02it/s]
# Removing background: Apple___Apple_scab:   9%|████████                                                                                  | 180/2016 [03:00<29:46,  1.03it/s]
# Removing background: Apple___Apple_scab:   9%|████████                                                                                  | 181/2016 [03:01<30:45,  1.01s/it]
# Removing background: Apple___Apple_scab:   9%|████████▏                                                                                 | 182/2016 [03:02<30:31,  1.00it/s]
# Removing background: Apple___Apple_scab:   9%|████████▏                                                                                 | 183/2016 [03:03<31:01,  1.02s/it]
# Removing background: Apple___Apple_scab:   9%|████████▏                                                                                 | 184/2016 [03:04<30:25,  1.00it/s]
# Removing background: Apple___Apple_scab:   9%|████████▎                                                                                 | 185/2016 [03:05<30:31,  1.00s/it]
# Removing background: Apple___Apple_scab:   9%|████████▎                                                                                 | 186/2016 [03:06<30:25,  1.00it/s]
# Removing background: Apple___Apple_scab:   9%|████████▎                                                                                 | 187/2016 [03:07<30:42,  1.01s/it]
# Removing background: Apple___Apple_scab:   9%|████████▍                                                                                 | 188/2016 [03:08<31:03,  1.02s/it]
# Removing background: Apple___Apple_scab:   9%|████████▍                                                                                 | 189/2016 [03:09<30:50,  1.01s/it]
# Removing background: Apple___Apple_scab:   9%|████████▍                                                                                 | 190/2016 [03:10<31:56,  1.05s/it]
# Removing background: Apple___Apple_scab:   9%|████████▌                                                                                 | 191/2016 [03:12<31:37,  1.04s/it]
# Removing background: Apple___Apple_scab:  10%|████████▌                                                                                 | 192/2016 [03:12<30:51,  1.02s/it]
# Removing background: Apple___Apple_scab:  10%|████████▌                                                                                 | 193/2016 [03:13<30:20,  1.00it/s]
# Removing background: Apple___Apple_scab:  10%|████████▋                                                                                 | 194/2016 [03:15<31:03,  1.02s/it]
# Removing background: Apple___Apple_scab:  10%|████████▋                                                                                 | 195/2016 [03:16<31:21,  1.03s/it]
# Removing background: Apple___Apple_scab:  10%|████████▊                                                                                 | 196/2016 [03:17<31:37,  1.04s/it]
# Removing background: Apple___Apple_scab:  10%|████████▊                                                                                 | 197/2016 [03:18<32:42,  1.08s/it]
# Removing background: Apple___Apple_scab:  10%|████████▊                                                                                 | 198/2016 [03:19<32:03,  1.06s/it]
# Removing background: Apple___Apple_scab:  10%|████████▉                                                                                 | 199/2016 [03:20<31:26,  1.04s/it]
# Removing background: Apple___Apple_scab:  10%|████████▉                                                                                 | 200/2016 [03:21<31:59,  1.06s/it]
# Removing background: Apple___Apple_scab:  10%|████████▉                                                                                 | 201/2016 [03:22<31:39,  1.05s/it]
# Removing background: Apple___Apple_scab:  10%|█████████                                                                                 | 202/2016 [03:23<31:28,  1.04s/it]
# Removing background: Apple___Apple_scab:  10%|█████████                                                                                 | 203/2016 [03:24<31:17,  1.04s/it]
# Removing background: Apple___Apple_scab:  10%|█████████                                                                                 | 204/2016 [03:25<31:02,  1.03s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▏                                                                                | 205/2016 [03:26<30:45,  1.02s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▏                                                                                | 206/2016 [03:27<30:54,  1.02s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▏                                                                                | 207/2016 [03:28<31:24,  1.04s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▎                                                                                | 208/2016 [03:29<30:59,  1.03s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▎                                                                                | 209/2016 [03:30<30:54,  1.03s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▍                                                                                | 210/2016 [03:31<30:41,  1.02s/it]
# Removing background: Apple___Apple_scab:  10%|█████████▍                                                                                | 211/2016 [03:32<30:06,  1.00s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▍                                                                                | 212/2016 [03:33<29:31,  1.02it/s]
# Removing background: Apple___Apple_scab:  11%|█████████▌                                                                                | 213/2016 [03:34<29:51,  1.01it/s]
# Removing background: Apple___Apple_scab:  11%|█████████▌                                                                                | 214/2016 [03:35<30:00,  1.00it/s]
# Removing background: Apple___Apple_scab:  11%|█████████▌                                                                                | 215/2016 [03:36<30:23,  1.01s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▋                                                                                | 216/2016 [03:37<30:10,  1.01s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▋                                                                                | 217/2016 [03:38<30:32,  1.02s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▋                                                                                | 218/2016 [03:39<30:34,  1.02s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▊                                                                                | 219/2016 [03:40<30:36,  1.02s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▊                                                                                | 220/2016 [03:41<30:34,  1.02s/it]
# Removing background: Apple___Apple_scab:  11%|█████████▊                                                                                | 221/2016 [03:42<29:53,  1.00it/s]
# Removing background: Apple___Apple_scab:  11%|█████████▉                                                                                | 222/2016 [03:43<29:50,  1.00it/s]
# Removing background: Apple___Apple_scab:  11%|█████████▉                                                                                | 223/2016 [03:44<29:58,  1.00s/it]
# Removing background: Apple___Apple_scab:  11%|██████████                                                                                | 224/2016 [03:45<29:47,  1.00it/s]
# Removing background: Apple___Apple_scab:  11%|██████████                                                                                | 225/2016 [03:46<29:52,  1.00s/it]
# Removing background: Apple___Apple_scab:  11%|██████████                                                                                | 226/2016 [03:47<29:54,  1.00s/it]
# Removing background: Apple___Apple_scab:  11%|██████████▏                                                                               | 227/2016 [03:48<29:27,  1.01it/s]
# Removing background: Apple___Apple_scab:  11%|██████████▏                                                                               | 228/2016 [03:49<30:06,  1.01s/it]
# Removing background: Apple___Apple_scab:  11%|██████████▏                                                                               | 229/2016 [03:50<29:43,  1.00it/s]
# Removing background: Apple___Apple_scab:  11%|██████████▎                                                                               | 230/2016 [03:51<30:16,  1.02s/it]
# Removing background: Apple___Apple_scab:  11%|██████████▎                                                                               | 231/2016 [03:52<29:42,  1.00it/s]
# Removing background: Apple___Apple_scab:  12%|██████████▎                                                                               | 232/2016 [03:53<29:33,  1.01it/s]
# Removing background: Apple___Apple_scab:  12%|██████████▍                                                                               | 233/2016 [03:54<30:18,  1.02s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▍                                                                               | 234/2016 [03:55<30:23,  1.02s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▍                                                                               | 235/2016 [03:56<30:27,  1.03s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▌                                                                               | 236/2016 [03:57<30:29,  1.03s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▌                                                                               | 237/2016 [03:58<30:22,  1.02s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▋                                                                               | 238/2016 [03:59<29:59,  1.01s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▋                                                                               | 239/2016 [04:00<29:28,  1.01it/s]
# Removing background: Apple___Apple_scab:  12%|██████████▋                                                                               | 240/2016 [04:01<29:38,  1.00s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▊                                                                               | 241/2016 [04:02<29:37,  1.00s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▊                                                                               | 242/2016 [04:03<29:51,  1.01s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▊                                                                               | 243/2016 [04:04<30:11,  1.02s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▉                                                                               | 244/2016 [04:05<29:41,  1.01s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▉                                                                               | 245/2016 [04:06<29:38,  1.00s/it]
# Removing background: Apple___Apple_scab:  12%|██████████▉                                                                               | 246/2016 [04:07<29:01,  1.02it/s]
# Removing background: Apple___Apple_scab:  12%|███████████                                                                               | 247/2016 [04:08<29:26,  1.00it/s]
# Removing background: Apple___Apple_scab:  12%|███████████                                                                               | 248/2016 [04:09<29:17,  1.01it/s]
# Removing background: Apple___Apple_scab:  12%|███████████                                                                               | 249/2016 [04:10<29:12,  1.01it/s]
# Removing background: Apple___Apple_scab:  12%|███████████▏                                                                              | 250/2016 [04:11<29:15,  1.01it/s]
# Removing background: Apple___Apple_scab:  12%|███████████▏                                                                              | 251/2016 [04:12<29:09,  1.01it/s]
# Removing background: Apple___Apple_scab:  12%|███████████▎                                                                              | 252/2016 [04:13<28:31,  1.03it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▎                                                                              | 253/2016 [04:14<28:47,  1.02it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▎                                                                              | 254/2016 [04:15<28:57,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▍                                                                              | 255/2016 [04:16<29:12,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▍                                                                              | 256/2016 [04:17<28:40,  1.02it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▍                                                                              | 257/2016 [04:18<28:52,  1.02it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▌                                                                              | 258/2016 [04:19<29:15,  1.00it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▌                                                                              | 259/2016 [04:20<29:16,  1.00it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▌                                                                              | 260/2016 [04:21<28:59,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▋                                                                              | 261/2016 [04:22<28:46,  1.02it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▋                                                                              | 262/2016 [04:23<29:02,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▋                                                                              | 263/2016 [04:24<28:49,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▊                                                                              | 264/2016 [04:25<28:47,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▊                                                                              | 265/2016 [04:26<28:45,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▉                                                                              | 266/2016 [04:27<28:52,  1.01it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▉                                                                              | 267/2016 [04:28<28:41,  1.02it/s]
# Removing background: Apple___Apple_scab:  13%|███████████▉                                                                              | 268/2016 [04:29<29:12,  1.00s/it]
# Removing background: Apple___Apple_scab:  13%|████████████                                                                              | 269/2016 [04:30<30:24,  1.04s/it]
# Removing background: Apple___Apple_scab:  13%|████████████                                                                              | 270/2016 [04:31<30:08,  1.04s/it]
# Removing background: Apple___Apple_scab:  13%|████████████                                                                              | 271/2016 [04:32<30:14,  1.04s/it]
# Removing background: Apple___Apple_scab:  13%|████████████▏                                                                             | 272/2016 [04:33<30:00,  1.03s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▏                                                                             | 273/2016 [04:34<30:07,  1.04s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▏                                                                             | 274/2016 [04:35<30:20,  1.04s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▎                                                                             | 275/2016 [04:36<30:04,  1.04s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▎                                                                             | 276/2016 [04:37<29:44,  1.03s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▎                                                                             | 277/2016 [04:38<29:22,  1.01s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▍                                                                             | 278/2016 [04:39<29:30,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▍                                                                             | 279/2016 [04:40<29:36,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▌                                                                             | 280/2016 [04:41<29:15,  1.01s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▌                                                                             | 281/2016 [04:43<29:25,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▌                                                                             | 282/2016 [04:44<29:39,  1.03s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▋                                                                             | 283/2016 [04:45<29:41,  1.03s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▋                                                                             | 284/2016 [04:46<29:26,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▋                                                                             | 285/2016 [04:47<29:23,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▊                                                                             | 286/2016 [04:48<28:56,  1.00s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▊                                                                             | 287/2016 [04:49<29:26,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▊                                                                             | 288/2016 [04:50<29:30,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▉                                                                             | 289/2016 [04:51<29:25,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▉                                                                             | 290/2016 [04:52<29:28,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|████████████▉                                                                             | 291/2016 [04:53<29:23,  1.02s/it]
# Removing background: Apple___Apple_scab:  14%|█████████████                                                                             | 292/2016 [04:54<29:19,  1.02s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████                                                                             | 293/2016 [04:55<29:07,  1.01s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▏                                                                            | 294/2016 [04:56<28:43,  1.00s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▏                                                                            | 295/2016 [04:57<28:42,  1.00s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▏                                                                            | 296/2016 [04:58<28:33,  1.00it/s]
# Removing background: Apple___Apple_scab:  15%|█████████████▎                                                                            | 297/2016 [04:59<28:27,  1.01it/s]
# Removing background: Apple___Apple_scab:  15%|█████████████▎                                                                            | 298/2016 [05:00<28:37,  1.00it/s]
# Removing background: Apple___Apple_scab:  15%|█████████████▎                                                                            | 299/2016 [05:01<29:17,  1.02s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▍                                                                            | 300/2016 [05:02<28:56,  1.01s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▍                                                                            | 301/2016 [05:03<29:29,  1.03s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▍                                                                            | 302/2016 [05:04<29:52,  1.05s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▌                                                                            | 303/2016 [05:05<29:44,  1.04s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▌                                                                            | 304/2016 [05:06<29:05,  1.02s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▌                                                                            | 305/2016 [05:07<29:19,  1.03s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▋                                                                            | 306/2016 [05:08<29:11,  1.02s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▋                                                                            | 307/2016 [05:09<30:02,  1.05s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▊                                                                            | 308/2016 [05:10<29:57,  1.05s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▊                                                                            | 309/2016 [05:11<29:37,  1.04s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▊                                                                            | 310/2016 [05:12<29:07,  1.02s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▉                                                                            | 311/2016 [05:13<29:18,  1.03s/it]
# Removing background: Apple___Apple_scab:  15%|█████████████▉                                                                            | 312/2016 [05:14<28:45,  1.01s/it]
# Removing background: Apple___Apple_scab:  16%|█████████████▉                                                                            | 313/2016 [05:15<28:37,  1.01s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████                                                                            | 314/2016 [05:16<28:24,  1.00s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████                                                                            | 315/2016 [05:17<28:39,  1.01s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████                                                                            | 316/2016 [05:18<29:53,  1.05s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▏                                                                           | 317/2016 [05:19<29:55,  1.06s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▏                                                                           | 318/2016 [05:20<29:26,  1.04s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▏                                                                           | 319/2016 [05:21<29:20,  1.04s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▎                                                                           | 320/2016 [05:22<29:09,  1.03s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▎                                                                           | 321/2016 [05:23<29:08,  1.03s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▎                                                                           | 322/2016 [05:24<28:51,  1.02s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▍                                                                           | 323/2016 [05:25<28:39,  1.02s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▍                                                                           | 324/2016 [05:27<28:54,  1.03s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▌                                                                           | 325/2016 [05:28<28:48,  1.02s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▌                                                                           | 326/2016 [05:29<28:45,  1.02s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▌                                                                           | 327/2016 [05:30<28:41,  1.02s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▋                                                                           | 328/2016 [05:31<28:47,  1.02s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▋                                                                           | 329/2016 [05:32<28:50,  1.03s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▋                                                                           | 330/2016 [05:33<28:52,  1.03s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▊                                                                           | 331/2016 [05:34<29:32,  1.05s/it]
# Removing background: Apple___Apple_scab:  16%|██████████████▊                                                                           | 332/2016 [05:35<29:53,  1.07s/it]
# Removing background: Apple___Apple_scab:  17%|██████████████▊                                                                           | 333/2016 [05:36<29:43,  1.06s/it]
# ...
# Removing background: Apple___Cedar_apple_rust:  56%|███████████████████████████████████████████████▎                                    | 992/1760 [17:01<13:09,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  56%|███████████████████████████████████████████████▍                                    | 993/1760 [17:02<12:58,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  56%|███████████████████████████████████████████████▍                                    | 994/1760 [17:03<12:59,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▍                                    | 995/1760 [17:04<13:07,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▌                                    | 996/1760 [17:05<13:13,  1.04s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▌                                    | 997/1760 [17:06<13:03,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▋                                    | 998/1760 [17:07<13:14,  1.04s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▋                                    | 999/1760 [17:08<13:19,  1.05s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▏                                   | 1000/1760 [17:09<13:33,  1.07s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▏                                   | 1001/1760 [17:10<13:15,  1.05s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▎                                   | 1002/1760 [17:11<13:17,  1.05s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▎                                   | 1003/1760 [17:12<13:08,  1.04s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▎                                   | 1004/1760 [17:13<12:57,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▍                                   | 1005/1760 [17:14<12:46,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▍                                   | 1006/1760 [17:15<12:38,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▍                                   | 1007/1760 [17:16<12:34,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▌                                   | 1008/1760 [17:17<12:34,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▌                                   | 1009/1760 [17:18<12:41,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▋                                   | 1010/1760 [17:19<12:38,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▋                                   | 1011/1760 [17:20<12:35,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  57%|███████████████████████████████████████████████▋                                   | 1012/1760 [17:21<12:32,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|███████████████████████████████████████████████▊                                   | 1013/1760 [17:23<12:41,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|███████████████████████████████████████████████▊                                   | 1014/1760 [17:24<12:35,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|███████████████████████████████████████████████▊                                   | 1015/1760 [17:25<12:51,  1.04s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|███████████████████████████████████████████████▉                                   | 1016/1760 [17:26<13:08,  1.06s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|███████████████████████████████████████████████▉                                   | 1017/1760 [17:27<13:14,  1.07s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████                                   | 1018/1760 [17:28<12:59,  1.05s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████                                   | 1019/1760 [17:29<12:47,  1.04s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████                                   | 1020/1760 [17:30<12:39,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▏                                  | 1021/1760 [17:31<12:36,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▏                                  | 1022/1760 [17:32<12:32,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▏                                  | 1023/1760 [17:33<12:33,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▎                                  | 1024/1760 [17:34<12:29,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▎                                  | 1025/1760 [17:35<12:38,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▍                                  | 1026/1760 [17:36<12:34,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▍                                  | 1027/1760 [17:37<12:28,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▍                                  | 1028/1760 [17:38<12:12,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  58%|████████████████████████████████████████████████▌                                  | 1029/1760 [17:39<12:08,  1.00it/s]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▌                                  | 1030/1760 [17:40<12:09,  1.00it/s]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▌                                  | 1031/1760 [17:41<12:04,  1.01it/s]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▋                                  | 1032/1760 [17:42<12:03,  1.01it/s]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▋                                  | 1033/1760 [17:43<11:52,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▊                                  | 1034/1760 [17:44<12:18,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▊                                  | 1035/1760 [17:45<12:32,  1.04s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▊                                  | 1036/1760 [17:46<12:26,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▉                                  | 1037/1760 [17:47<12:26,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▉                                  | 1038/1760 [17:48<12:14,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|████████████████████████████████████████████████▉                                  | 1039/1760 [17:49<12:04,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████                                  | 1040/1760 [17:50<12:01,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████                                  | 1041/1760 [17:51<12:11,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████▏                                 | 1042/1760 [17:52<12:00,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████▏                                 | 1043/1760 [17:53<12:02,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████▏                                 | 1044/1760 [17:54<12:03,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████▎                                 | 1045/1760 [17:55<12:05,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████▎                                 | 1046/1760 [17:56<12:14,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  59%|█████████████████████████████████████████████████▍                                 | 1047/1760 [17:57<12:12,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▍                                 | 1048/1760 [17:58<12:07,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▍                                 | 1049/1760 [17:59<12:09,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▌                                 | 1050/1760 [18:00<12:03,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▌                                 | 1051/1760 [18:01<11:50,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▌                                 | 1052/1760 [18:02<11:48,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▋                                 | 1053/1760 [18:03<11:56,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▋                                 | 1054/1760 [18:04<11:53,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▊                                 | 1055/1760 [18:05<11:55,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▊                                 | 1056/1760 [18:06<11:38,  1.01it/s]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▊                                 | 1057/1760 [18:07<11:43,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▉                                 | 1058/1760 [18:08<11:45,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▉                                 | 1059/1760 [18:09<11:53,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|█████████████████████████████████████████████████▉                                 | 1060/1760 [18:10<11:41,  1.00s/it]
# Removing background: Apple___Cedar_apple_rust:  60%|██████████████████████████████████████████████████                                 | 1061/1760 [18:11<11:27,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  60%|██████████████████████████████████████████████████                                 | 1062/1760 [18:12<11:26,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  60%|██████████████████████████████████████████████████▏                                | 1063/1760 [18:13<11:26,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  60%|██████████████████████████████████████████████████▏                                | 1064/1760 [18:14<11:21,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▏                                | 1065/1760 [18:15<11:11,  1.03it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▎                                | 1066/1760 [18:16<11:14,  1.03it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▎                                | 1067/1760 [18:17<11:17,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▎                                | 1068/1760 [18:18<11:15,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▍                                | 1069/1760 [18:19<11:11,  1.03it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▍                                | 1070/1760 [18:20<11:13,  1.03it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▌                                | 1071/1760 [18:21<11:13,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▌                                | 1072/1760 [18:22<11:16,  1.02it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▌                                | 1073/1760 [18:23<11:19,  1.01it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▋                                | 1074/1760 [18:24<11:24,  1.00it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▋                                | 1075/1760 [18:25<11:24,  1.00it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▋                                | 1076/1760 [18:26<11:22,  1.00it/s]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▊                                | 1077/1760 [18:27<11:36,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▊                                | 1078/1760 [18:28<11:35,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▉                                | 1079/1760 [18:29<11:33,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▉                                | 1080/1760 [18:30<11:26,  1.01s/it]
# Removing background: Apple___Cedar_apple_rust:  61%|██████████████████████████████████████████████████▉                                | 1081/1760 [18:31<11:40,  1.03s/it]
# Removing background: Apple___Cedar_apple_rust:  61%|███████████████████████████████████████████████████                                | 1082/1760 [18:32<11:34,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  62%|███████████████████████████████████████████████████                                | 1083/1760 [18:33<11:27,  1.02s/it]
# Removing background: Apple___Cedar_apple_rust:  62%|███████████████████████████████████████████████████                                | 1084/1760 [18:34<11:11,  1.01it/s]
